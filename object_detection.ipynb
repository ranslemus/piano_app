# %%
from ultralytics import YOLO

# %%
model = YOLO("yolo11n.pt")  # or yolo11s.pt, yolo11m.pt

# %%
model.train(
    data="D:\college\Rechordnizer\streamlit_app\piano_data.yolov11.zip",
    epochs=100,
    imgsz=640,
    batch=16,
    device=0   # first GPU
)
# Out:
# Ultralytics 8.3.239  Python-3.10.19 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce GTX 1050 Ti, 4096MiB)
# ...
